# %%
import sys
# !{sys.executable} -m pip install altair vega vega_datasets

# %%
import altair as alt

import pandas as pd
from altair.utils.display import RendererRegistry

data = pd.DataFrame({'a': list('CCCDDDEEE'),
                     'b': [2, 7, 4, 1, 2, 6, 8, 4, 7]})

data = pd.read_csv("ai-training-computation.csv")

alt.Chart(data).mark_point(clip=True).encode(
    alt.Y('Training_computation_petaflop', scale=alt.Scale(type='log')), alt.X('year', scale=alt.Scale(domain=(1997, 2025)))
)
# VEGALITE_MIME_TYPE = "application/vnd.vegalite.v3+json"  # type: str

# ENTRY_POINT_GROUP = "altair.vegalite.v3.renderer"  # type: str
# renderers = RendererRegistry(entry_point_group=ENTRY_POINT_GROUP).enable('notebook')
# alt.renderers.enable('notebook')
# RendererRegistry.enable('notebook')
# alt.renderers.enable('html')
# alt.renderers.enable('mimetype')
# alt.renderers.enable('notebook')
# alt.renderers.enable('default')
# Out:
# alt.Chart(...)
